# %%
# Installing Required Packages
# !pip install torch
# !pip install torch-geometric
# !pip install tensorboard
# !pip install pandas
# !pip install scikit-learn
# !pip install tqdm
# !pip install lxml
# !pip install scipy
# !pip install pyproj
# !pip install networkx
# !pip install pyyaml
# !pip install pillow
# !pip install folium
# !pip install geojson
# !pip install h5py
# !pip install gdal
# !pip install geopandas
# !pip install optuna
# !pip install sqlalchemy
# !pip install pytest
# !pip install matplotlib
# !pip install seaborn
# !pip install hydra-core
# !pip install pygmo
# !pip install argcomplete
# !pip install jsonpath-ng
# !pip install plotly
# Out:
# Requirement already satisfied: torch in c:\users\owner\appdata\roaming\python\python39\site-packages (2.5.1)
# Collecting filelock (from torch)
#   Using cached filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from torch) (4.12.2)
# Collecting networkx (from torch)
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jinja2 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from torch) (3.1.5)
# Collecting fsspec (from torch)
#   Using cached fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting sympy==1.13.1 (from torch)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from jinja2->torch) (3.0.2)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached filelock-3.17.0-py3-none-any.whl (16 kB)
# Using cached fsspec-2025.2.0-py3-none-any.whl (184 kB)
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.6 MB 1.2 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------- -------- 1.3/1.6 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.8 MB/s eta 0:00:00
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, networkx, fsspec, filelock
# Successfully installed filelock-3.17.0 fsspec-2025.2.0 mpmath-1.3.0 networkx-3.2.1 sympy-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lightning 2.5.0.post0 requires tqdm<6.0,>=4.57.0, which is not installed.
# pytorch-lightning 2.5.0.post0 requires tqdm>=4.57.0, which is not installed.
# rl4co 0.5.1 requires matplotlib, which is not installed.
# rl4co 0.5.1 requires pyrootutils, which is not installed.
# rl4co 0.5.1 requires scipy, which is not installed.
# torchmetrics 1.6.1 requires numpy>1.20.0, which is not installed.
# torchrl 0.6.0 requires numpy, which is not installed.
# Collecting torch-geometric
#   Using cached torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: aiohttp in c:\users\owner\appdata\roaming\python\python39\site-packages (from torch-geometric) (3.11.11)
# Requirement already satisfied: fsspec in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from torch-geometric) (2025.2.0)
# Requirement already satisfied: jinja2 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from torch-geometric) (3.1.5)
# Collecting numpy (from torch-geometric)
#   Downloading numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from torch-geometric) (5.9.0)
# Collecting pyparsing (from torch-geometric)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: requests in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from torch-geometric) (2.32.3)
# Collecting tqdm (from torch-geometric)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\owner\appdata\roaming\python\python39\site-packages (from aiohttp->torch-geometric) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\owner\appdata\roaming\python\python39\site-packages (from aiohttp->torch-geometric) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\owner\appdata\roaming\python\python39\site-packages (from aiohttp->torch-geometric) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from aiohttp->torch-geometric) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\owner\appdata\roaming\python\python39\site-packages (from aiohttp->torch-geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\owner\appdata\roaming\python\python39\site-packages (from aiohttp->torch-geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\owner\appdata\roaming\python\python39\site-packages (from aiohttp->torch-geometric) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\owner\appdata\roaming\python\python39\site-packages (from aiohttp->torch-geometric) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from jinja2->torch-geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from requests->torch-geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from requests->torch-geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from requests->torch-geometric) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from requests->torch-geometric) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from tqdm->torch-geometric) (0.4.6)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from multidict<7.0,>=4.5->aiohttp->torch-geometric) (4.12.2)
# Using cached torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
# Downloading numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
#    ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#    ----- ---------------------------------- 2.4/15.9 MB 13.4 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/15.9 MB 13.9 MB/s eta 0:00:01
#    --------------------- ------------------ 8.4/15.9 MB 14.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.3/15.9 MB 13.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.9/15.9 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.9 MB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 15.9/15.9 MB 12.2 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, pyparsing, numpy, torch-geometric
# Successfully installed numpy-2.0.2 pyparsing-3.2.1 torch-geometric-2.6.1 tqdm-4.67.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rl4co 0.5.1 requires matplotlib, which is not installed.
# rl4co 0.5.1 requires pyrootutils, which is not installed.
# rl4co 0.5.1 requires scipy, which is not installed.
# Collecting tensorboard
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting absl-py>=0.4 (from tensorboard)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Downloading grpcio-1.70.0-cp39-cp39-win_amd64.whl.metadata (4.0 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from tensorboard) (2.0.2)
# Requirement already satisfied: packaging in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from tensorboard) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\owner\appdata\roaming\python\python39\site-packages (from tensorboard) (5.29.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from tensorboard) (75.8.0)
# Requirement already satisfied: six>1.9 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from tensorboard) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from markdown>=2.6.8->tensorboard) (8.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.21.0)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.5 MB 989.2 kB/s eta 0:00:06
#    ----- ---------------------------------- 0.8/5.5 MB 1.2 MB/s eta 0:00:05
#    --------- ------------------------------ 1.3/5.5 MB 1.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.6/5.5 MB 1.4 MB/s eta 0:00:03
#    --------------- ------------------------ 2.1/5.5 MB 1.5 MB/s eta 0:00:03
#    ------------------- -------------------- 2.6/5.5 MB 1.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.1/5.5 MB 1.8 MB/s eta 0:00:02
#    -------------------------- ------------- 3.7/5.5 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 4.2/5.5 MB 2.0 MB/s eta 0:00:01
#    -------------------------------- ------- 4.5/5.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.7/5.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 1.7 MB/s eta 0:00:00
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading grpcio-1.70.0-cp39-cp39-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.3 MB 1.2 MB/s eta 0:00:04
#    --------- ------------------------------ 1.0/4.3 MB 1.5 MB/s eta 0:00:03
#    --------- ------------------------------ 1.0/4.3 MB 1.5 MB/s eta 0:00:03
#    ------------ --------------------------- 1.3/4.3 MB 1.1 MB/s eta 0:00:03
#    -------------- ------------------------- 1.6/4.3 MB 1.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 1.8/4.3 MB 1.2 MB/s eta 0:00:03
#    --------------------- ------------------ 2.4/4.3 MB 1.3 MB/s eta 0:00:02
#    ------------------------ --------------- 2.6/4.3 MB 1.3 MB/s eta 0:00:02
#    ------------------------ --------------- 2.6/4.3 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 3.1/4.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.7/4.3 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 3.9/4.3 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 4.2/4.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 1.4 MB/s eta 0:00:00
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Installing collected packages: werkzeug, tensorboard-data-server, grpcio, absl-py, markdown, tensorboard
# Successfully installed absl-py-2.1.0 grpcio-1.70.0 markdown-3.7 tensorboard-2.19.0 tensorboard-data-server-0.7.2 werkzeug-3.1.3
# Collecting pandas
#   Downloading pandas-2.2.3-cp39-cp39-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp39-cp39-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    --------- ------------------------------ 2.6/11.6 MB 18.9 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.6 MB 17.5 MB/s eta 0:00:01
#    ------------------------------ --------- 8.9/11.6 MB 15.8 MB/s eta 0:00:01
#    -------------------------------------- - 11.3/11.6 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 11.5 MB/s eta 0:00:00
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2025.1 tzdata-2025.1
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from scikit-learn) (2.0.2)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.2 MB 12.7 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/11.2 MB 6.4 MB/s eta 0:00:02
#    ------------- -------------------------- 3.7/11.2 MB 6.1 MB/s eta 0:00:02
#    --------------- ------------------------ 4.5/11.2 MB 5.4 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.2 MB 5.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.2 MB 5.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/11.2 MB 5.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.2 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.5/11.2 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 5.4 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#     --------------------------------------- 1.0/46.2 MB 4.2 MB/s eta 0:00:11
#    -- ------------------------------------- 3.4/46.2 MB 7.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 5.0/46.2 MB 8.4 MB/s eta 0:00:05
#    ----- ---------------------------------- 6.8/46.2 MB 7.8 MB/s eta 0:00:06
#    ------ --------------------------------- 7.6/46.2 MB 7.0 MB/s eta 0:00:06
#    ------- -------------------------------- 8.9/46.2 MB 6.8 MB/s eta 0:00:06
#    -------- ------------------------------- 10.0/46.2 MB 7.1 MB/s eta 0:00:06
#    -------- ------------------------------- 10.0/46.2 MB 7.1 MB/s eta 0:00:06
#    -------- ------------------------------- 10.2/46.2 MB 5.3 MB/s eta 0:00:07
#    ---------- ----------------------------- 12.6/46.2 MB 5.8 MB/s eta 0:00:06
#    ------------- -------------------------- 15.5/46.2 MB 6.5 MB/s eta 0:00:05
#    ---------------- ----------------------- 18.6/46.2 MB 7.2 MB/s eta 0:00:04
#    ------------------ --------------------- 21.8/46.2 MB 7.8 MB/s eta 0:00:04
#    ----------------------- ---------------- 26.7/46.2 MB 8.9 MB/s eta 0:00:03
#    -------------------------- ------------- 31.2/46.2 MB 9.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 34.3/46.2 MB 10.0 MB/s eta 0:00:02
#    -------------------------------- ------- 37.7/46.2 MB 10.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.9/46.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------------- - 44.3/46.2 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 8.8 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.13.1 threadpoolctl-3.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rl4co 0.5.1 requires matplotlib, which is not installed.
# rl4co 0.5.1 requires pyrootutils, which is not installed.
# Requirement already satisfied: tqdm in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from tqdm) (0.4.6)
# Collecting lxml
#   Downloading lxml-5.3.1-cp39-cp39-win_amd64.whl.metadata (3.8 kB)
# Downloading lxml-5.3.1-cp39-cp39-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------- ----------------- 2.1/3.8 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 14.2 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-5.3.1
# Requirement already satisfied: scipy in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from scipy) (2.0.2)
# Collecting pyproj
#   Downloading pyproj-3.6.1-cp39-cp39-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: certifi in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pyproj) (2025.1.31)
# Downloading pyproj-3.6.1-cp39-cp39-win_amd64.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.1 MB 1.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.0/6.1 MB 1.6 MB/s eta 0:00:04
#    -------- ------------------------------- 1.3/6.1 MB 1.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 1.6/6.1 MB 1.6 MB/s eta 0:00:03
#    ------------ --------------------------- 1.8/6.1 MB 1.5 MB/s eta 0:00:03
#    --------------- ------------------------ 2.4/6.1 MB 1.6 MB/s eta 0:00:03
#    ------------------ --------------------- 2.9/6.1 MB 1.6 MB/s eta 0:00:02
#    -------------------- ------------------- 3.1/6.1 MB 1.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.4/6.1 MB 1.6 MB/s eta 0:00:02
#    ------------------------ --------------- 3.7/6.1 MB 1.6 MB/s eta 0:00:02
#    --------------------------- ------------ 4.2/6.1 MB 1.6 MB/s eta 0:00:02
#    ------------------------------ --------- 4.7/6.1 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 5.5/6.1 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.1 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 1.8 MB/s eta 0:00:00
# Installing collected packages: pyproj
# Successfully installed pyproj-3.6.1
# Requirement already satisfied: networkx in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (3.2.1)
# Requirement already satisfied: pyyaml in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (6.0.2)
# Collecting pillow
#   Downloading pillow-11.1.0-cp39-cp39-win_amd64.whl.metadata (9.3 kB)
# Downloading pillow-11.1.0-cp39-cp39-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.6 MB ? eta -:--:--
#    ---------------------------------------  2.6/2.6 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 6.9 MB/s eta 0:00:00
# Installing collected packages: pillow
# Successfully installed pillow-11.1.0
# Collecting folium
#   Downloading folium-0.19.4-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from folium) (3.1.5)
# Requirement already satisfied: numpy in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from folium) (2.32.3)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2025.1.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from requests->folium) (2025.1.31)
# Downloading folium-0.19.4-py2.py3-none-any.whl (110 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading xyzservices-2025.1.0-py3-none-any.whl (88 kB)
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.8.1 folium-0.19.4 xyzservices-2025.1.0
# Collecting geojson
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: geojson
# Successfully installed geojson-3.2.0
# Collecting h5py
#   Downloading h5py-3.13.0-cp39-cp39-win_amd64.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from h5py) (2.0.2)
# Downloading h5py-3.13.0-cp39-cp39-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/3.0 MB 16.4 MB/s eta 0:00:01
#    -------------------------------------- - 2.9/3.0 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.0/3.0 MB 10.8 MB/s eta 0:00:00
# Installing collected packages: h5py
# Successfully installed h5py-3.13.0
# Collecting gdal
#   Downloading gdal-3.10.2.tar.gz (838 kB)
#      ---------------------------------------- 0.0/838.1 kB ? eta -:--:--
#      ------------ --------------------------- 262.1/838.1 kB ? eta -:--:--
#      ------------------------------------- 838.1/838.1 kB 12.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: gdal
#   Building wheel for gdal (pyproject.toml): started
#   Building wheel for gdal (pyproject.toml): finished with status 'error'
# Failed to build gdal
#   error: subprocess-exited-with-error
#
#   Building wheel for gdal (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [126 lines of output]
#   C:\Users\Owner\AppData\Local\Temp\pip-build-env-vgwa83gu\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:81: SetuptoolsWarning: `extras_require` overwritten in `pyproject.toml` (optional-dependencies)
#     corresp(dist, value, root_dir)
#   Using numpy 2.0.2
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-39\osgeo
#   copying osgeo\gdal.py -> build\lib.win-amd64-cpython-39\osgeo
#   copying osgeo\gdalconst.py -> build\lib.win-amd64-cpython-39\osgeo
#   copying osgeo\gdalnumeric.py -> build\lib.win-amd64-cpython-39\osgeo
#   copying osgeo\gdal_array.py -> build\lib.win-amd64-cpython-39\osgeo
#   copying osgeo\gnm.py -> build\lib.win-amd64-cpython-39\osgeo
#   copying osgeo\ogr.py -> build\lib.win-amd64-cpython-39\osgeo
#   copying osgeo\osr.py -> build\lib.win-amd64-cpython-39\osgeo
#   copying osgeo\__init__.py -> build\lib.win-amd64-cpython-39\osgeo
#   creating build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal2tiles.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal2xyz.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdalattachpct.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdalcompare.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdalmove.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_calc.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_edit.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_fillnodata.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_merge.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_pansharpen.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_polygonize.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_proximity.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_retile.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\gdal_sieve.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\ogrmerge.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\ogr_layer_algebra.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\pct2rgb.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\rgb2pct.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   copying gdal-utils\osgeo_utils\__init__.py -> build\lib.win-amd64-cpython-39\osgeo_utils
#   creating build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\array_util.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\base.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\batch_creator.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\color_palette.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\color_table.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\extent_util.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\gdal_argparse.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\numpy_util.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\osr_util.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\progress.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\raster_creation.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\rectangle.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\util.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   copying gdal-utils\osgeo_utils\auxiliary\__init__.py -> build\lib.win-amd64-cpython-39\osgeo_utils\auxiliary
#   creating build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\assemblepoly.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\build_jp2_from_xml.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\classify.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\crs2crs2grid.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\densify.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\dump_jp2.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\epsg_tr.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\esri2wkt.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\fft.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\fix_gpkg.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gcps2ogr.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gcps2vec.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gcps2wld.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal2grd.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalbuildvrtofvrt.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalchksum.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalcopyproj.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalfilter.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalident.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalimport.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdalinfo.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdallocationinfo.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_auth.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_cp.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_create_pdf.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_ls.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_lut.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_mkdir.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_remove_towgs84.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_rm.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_rmdir.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\gdal_vrtmerge.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\get_soundg.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\histrep.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\hsv_merge.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\jpeg_in_tiff_extract.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\load2odbc.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\loslas2ntv2.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\magphase.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\make_fuzzer_friendly_archive.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\mkgraticule.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\ogr2vrt.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\ogrinfo.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\ogrupdate.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\ogr_build_junction_table.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\ogr_dispatch.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\rel.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\tigerpoly.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\tile_extent_from_raster.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\tolatlong.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\validate_cloud_optimized_geotiff.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\validate_geoparquet.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\validate_gpkg.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\validate_jp2.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\val_repl.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\vec_tr.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\vec_tr_spat.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\wcs_virtds_params.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   copying gdal-utils\osgeo_utils\samples\__init__.py -> build\lib.win-amd64-cpython-39\osgeo_utils\samples
#   running egg_info
#   writing gdal-utils\GDAL.egg-info\PKG-INFO
#   writing dependency_links to gdal-utils\GDAL.egg-info\dependency_links.txt
#   writing entry points to gdal-utils\GDAL.egg-info\entry_points.txt
#   writing requirements to gdal-utils\GDAL.egg-info\requires.txt
#   writing top-level names to gdal-utils\GDAL.egg-info\top_level.txt
#   reading manifest file 'gdal-utils\GDAL.egg-info\SOURCES.txt'
#   writing manifest file 'gdal-utils\GDAL.egg-info\SOURCES.txt'
#   running build_ext
#   building 'osgeo._gdal' extension
#   building 'osgeo._gdalconst' extension
#   building 'osgeo._ogr' extension
#   building 'osgeo._gdal_array' extension
#   building 'osgeo._osr' extension
#   building 'osgeo._gnm' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for gdal
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (gdal)
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.22 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from geopandas) (2.0.2)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.10.0-cp39-cp39-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from geopandas) (3.6.1)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.0.7-cp39-cp39-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pandas>=1.4.0->geopandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pandas>=1.4.0->geopandas) (2025.1)
# Requirement already satisfied: certifi in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading pyogrio-0.10.0-cp39-cp39-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ---------- ----------------------------- 4.2/16.2 MB 21.0 MB/s eta 0:00:01
#    -------------------- ------------------- 8.1/16.2 MB 19.4 MB/s eta 0:00:01
#    ------------------------------- -------- 12.8/16.2 MB 20.1 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.2 MB 19.7 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 17.6 MB/s eta 0:00:00
# Downloading shapely-2.0.7-cp39-cp39-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 15.1 MB/s eta 0:00:00
# Installing collected packages: shapely, pyogrio, geopandas
# Successfully installed geopandas-1.0.1 pyogrio-0.10.0 shapely-2.0.7
# Collecting optuna
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: colorlog in c:\users\owner\appdata\roaming\python\python39\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from optuna) (24.2)
# Collecting sqlalchemy>=1.4.2 (from optuna)
#   Downloading SQLAlchemy-2.0.38-cp39-cp39-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: tqdm in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=1.4.2->optuna)
#   Downloading greenlet-3.1.1-cp39-cp39-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: colorama in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
# Downloading SQLAlchemy-2.0.38-cp39-cp39-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.1 MB 12.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 3.7 MB/s eta 0:00:00
# Downloading greenlet-3.1.1-cp39-cp39-win_amd64.whl (298 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
# Installing collected packages: Mako, greenlet, sqlalchemy, alembic, optuna
# Successfully installed Mako-1.3.9 alembic-1.14.1 greenlet-3.1.1 optuna-4.2.1 sqlalchemy-2.0.38
# Requirement already satisfied: sqlalchemy in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (2.0.38)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from sqlalchemy) (4.12.2)
# Collecting pytest
#   Downloading pytest-8.3.4-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: colorama in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pytest) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pytest) (1.2.0)
# Collecting iniconfig (from pytest)
#   Downloading iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: packaging in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pytest) (24.2)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pytest) (1.5.0)
# Requirement already satisfied: tomli>=1 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pytest) (2.0.1)
# Downloading pytest-8.3.4-py3-none-any.whl (343 kB)
# Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Installing collected packages: iniconfig, pytest
# Successfully installed iniconfig-2.0.0 pytest-8.3.4
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.56.0-cp39-cp39-win_amd64.whl.metadata (103 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/7.8 MB 16.6 MB/s eta 0:00:01
#    -------- ------------------------------- 1.6/7.8 MB 6.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/7.8 MB 3.2 MB/s eta 0:00:02
#    -------------------------- ------------- 5.2/7.8 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.8/7.8 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 6.2 MB/s eta 0:00:00
# Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp39-cp39-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------------------- ---------------- 1.3/2.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 7.3 MB/s eta 0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl (55 kB)
# Installing collected packages: kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.56.0 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rl4co 0.5.1 requires pyrootutils, which is not installed.
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Requirement already satisfied: hydra-core in c:\users\owner\appdata\roaming\python\python39\site-packages (1.3.2)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in c:\users\owner\appdata\roaming\python\python39\site-packages (from hydra-core) (2.3.0)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core)
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Requirement already satisfied: packaging in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from hydra-core) (24.2)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from omegaconf<2.4,>=2.2->hydra-core) (6.0.2)
# Installing collected packages: antlr4-python3-runtime
# Successfully installed antlr4-python3-runtime-4.9.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rl4co 0.5.1 requires pyrootutils, which is not installed.
# Collecting pygmo
#   Downloading pygmo-v2.19.0.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ------------------------ --------------- 1.8/3.0 MB 10.1 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 7.4 MB/s eta 0:00:00
# ERROR: pygmo from https://files.pythonhosted.org/packages/e2/12/090ba61479f60d5177a0048736d09dc028b2d65063ed44cb952df506336f/pygmo-v2.19.0.tar.gz does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# Collecting argcomplete
#   Downloading argcomplete-3.5.3-py3-none-any.whl.metadata (16 kB)
# Downloading argcomplete-3.5.3-py3-none-any.whl (43 kB)
# Installing collected packages: argcomplete
# Successfully installed argcomplete-3.5.3
# Collecting jsonpath-ng
#   Downloading jsonpath_ng-1.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: ply in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from jsonpath-ng) (3.11)
# Downloading jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Installing collected packages: jsonpath-ng
# Successfully installed jsonpath-ng-1.7.0
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.28.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in c:\users\owner\anaconda3\envs\dissertation\lib\site-packages (from plotly) (24.2)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/14.8 MB 12.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.6/14.8 MB 4.4 MB/s eta 0:00:03
#    ------ --------------------------------- 2.4/14.8 MB 4.1 MB/s eta 0:00:04
#    --------- ------------------------------ 3.7/14.8 MB 4.7 MB/s eta 0:00:03
#    ------------- -------------------------- 5.0/14.8 MB 5.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.3/14.8 MB 5.4 MB/s eta 0:00:02
#    -------------------- ------------------- 7.6/14.8 MB 5.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 8.7/14.8 MB 5.2 MB/s eta 0:00:02
#    -------------------------- ------------- 9.7/14.8 MB 5.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 10.7/14.8 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.8/14.8 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.8 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 14.8/14.8 MB 4.4 MB/s eta 0:00:00
# Downloading narwhals-1.28.0-py3-none-any.whl (308 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-1.28.0 plotly-6.0.0
